# %% [markdown]
# #Examen primer parcial
# 1. Resuelve el Ejercicio #3 del notebook
# 2. Crear un proyecto en VSC que contenga un menú con los 3 programas que contiene el notebook.
# 3. En el proyecto de VSC crear un entorno virtual (venv)
# 4. Activar el entorno virtual
# 5. Instalar la biblioteca de numpy
# 6. Crear una carpeta llamada **examenTuprimernombre** en la raíz del proyecto
# 7. Crea una carpeta llamada **resueltos** y coloca los ejercicios 1 y 2.
# 8. Crea una carpeta llamada **ejercicios** y coloca el ejercicio 3
# 9. Copiar el código a cada archivo del proyecto y convertirlo a función
# 11. Crear una carpeta llamada **menus** en la raíz del proyecto
# 13. Crear un archivo llamado **menu_principal.py** dentro de la carpeta menus
# 14. Crear una función con un menú para acceder a cada ejercicio (importar los archivos con sus funciones para poder invocarlas)
# 15. Crear archivo **main.py** en la raíz del proyecto que actúe como punto de partida del proyecto y realizar la llamada a la función menú principal.
# 16. Probar cada ejercicio con los respectivos casos de prueba.
# 17. Crea un documento de Word que cotenga:
# * Imagen del proyecto con las carpetas y archivos creados
# * El código de TODOS los archivos **.py** creados
# * Los casos de prueba de cada uno de los ejercicios que vienen en el notebook.
# * Guarda el archivo con el nombre evidenciasTuprimernombre.docx y conviértelo a formato PDF **evidenciasTuprimernombre.pdf**.
#
# ###**ESTE ARCHIVO ES MUY IMPORTANTE YA QUE SERÁ LA FORMA DE EVALUAR TU EXAMEN, DE NO CONTAR CON EL NO SE PODRÁ REVISAR EL EXAMEN.**

# %% [markdown]
# <h3 style="color:#2c3e50;">📋 Criterios de evaluación</h3>
#
# <table border="1" cellpadding="8" cellspacing="0" style="border-collapse: collapse; width: 100%; font-family: Arial, sans-serif;">
#   <thead>
#     <tr style="background-color:#1f4fd8; color:white; text-align:left;">
#       <th>Criterio</th>
#       <th style="text-align:center;">Puntos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background-color:#49A6EB;">
#       <td>Ejercicio 3: código y resultado correcto</td>
#       <td style="text-align:center; font-weight:bold;">2</td>
#     </tr>
#     <tr style="background-color:#eef3ff;">
#       <td>Proyecto en VS Code: entorno virtual, estructura del proyecto, ejercicios implementados en funciones y casos de prueba correctos</td>
#       <td style="text-align:center; font-weight:bold;">6</td>
#     </tr>
#     <tr style="background-color:#49A6EB;">
#       <td>Evidencia de resultados: archivo PDF con imágenes de la evidencia de prueba</td>
#       <td style="text-align:center; font-weight:bold;">2</td>
#     </tr>
#     <tr style="background-color:#dfe8ff;">
#       <td><strong>Total</strong></td>
#       <td style="text-align:center; font-weight:bold;"><strong>10</strong></td>
#     </tr>
#   </tbody>
# </table>
#
# <p style="margin-top:10px;">
#   <strong>Nota:</strong> Se descontará puntaje en cada rubro que no cumpla con los criterios establecidos en la tabla.
# </p>

# %% [markdown]
# ###Ejercicio #1
# Escriba un programa que pida dos números enteros y que calcule su división, escribiendo si la división es exacta o no.
# El programa tomar en cuenta que no se puede dividir por cero.
#
# ![image.png](data:image/png;base64,...).
#
# ![image.png](data:image/png;base64,...)

# %%
dividendo = float(input("Escriba el dividendo: "))
divisor = float(input("Escriba el divisor: "))

if divisor == 0:
  print('No se puede dividir por cero')
else:
  if dividendo % divisor == 0.0:
    print(f'La división es exacta. Cociente: {dividendo // divisor}')
  else:
    print(f'La división no es exacta. Cociente: {dividendo // divisor} Resto: {dividendo % divisor}')
# Out:
# Escriba el dividendo: 20
# Escriba el divisor: 0
# No se puede dividir por cero

# %% [markdown]
# ###Ejercicio #2
# Escriba un programa que pida los coeficientes de una ecuación de primer grado (a x + b = 0) y escriba la solución.
#
# Se recuerda que una ecuación de primer grado puede no tener solución, tener una solución única, o que todos los números sean solución. Se recuerda que la fórmula de las soluciones es x = -b / a
#
# Estos son algunos ejemplos de posibles respuestas (el orden de los ejemplos no tiene por qué corresponder con el orden de las condiciones):
#
# ![image.png](data:image/png;base64,...)

# %%
print('ECUACIÓN A X + B = 0')
a = float(input('Escriba el valor del coeficiente a: '))
b = float(input('Escriba el valor del coeficiente b: '))

if a == 0 and b == 0:
  print('Todos los números son solución')
else:
  if a == 0:
    print('La ecuación no tiene solución')
  else:
    x = -b / a
    print(f'La ecuación tiene una solución: {x}')
# Out:
# ECUACIÓN A X + B = 0
# Escriba el valor del coeficiente a: 0
# Escriba el valor del coeficiente b: 0
# Todos los números son solución

# %% [markdown]
# ###Ejercicio #3
# Escriba un programa que pida una distancia en centímetros y que escriba esa distancia en kilómetros, metros y centímetros (escribiendo todas las unidades). Si la distancia es 0 indique que se debe escribir una distancia mayor que cero.
#
# ![image.png](data:image/png;base64,...)
