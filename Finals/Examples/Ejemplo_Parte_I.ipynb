# %%
#Datos Caso de prueba 1, x = col1 y = col3
x=[130,650,99,150,128,302,95,945,368,961]
y=[186,699,132,272,291,331,199,1890,788,1601]
xk=386

# %%
#Datos Caso de prueba 2, x = col1 y = col4
x=[130,650,99,150,128,302,95,945,368,961]
y=[15,69.9,6.5,22.4,28.4,65.9,19.4,198.7,38.8,138.2]
xk=386

# %%
#Datos Caso de prueba 3, x = col2 y = col3
x=[163,765,141,166,137,355,136,1206,433,1130]
y=[186,699,132,272,291,331,199,1890,788,1601]
xk=386

# %%
#Datos Caso de prueba 4, x = col2 y = col4
x=[163,765,141,166,137,355,136,1206,433,1130]
y=[15,69.9,6.5,22.4,28.4,65.9,19.4,198.7,38.8,138.2]
xk=386

# %%
def calcularParametrosR2(x,y,xk):
  B0,B1,r,r2,yk=0,0,0,0
  #
  #Aquí van los cálculos
  #
  return B0,B1,r,r2,yk

def mostrarResultados(B0,B1,r,r2,yk):
  #
  # Aquí las instrucciones para mostrar resultados
  #
  pass

#Bloque principal
#Recuerda antes de ejecutar esta celda ejecutar la celda con los datos
#de prueba
B0,B1,r,r2,yk = calcularParametrosR2(x,y,xk)
mostrarResultados(B0,B1,r,r2,yk)

# %%
import scipy.special as sc

print(sc.gamma(4.5))
# Out:
# 11.63172839656745

# %%
def reglaSimpson(x,dof):
  p_ant = 0
  tol = 0.00001
  num_seg = 10
  while True:
       
    #aquí el proceso para calcular p y error

    if error < tol:
      break
    else:
      p_ant = p
      numseg = numseg * 2
  return p

#Bloque principal
x =
dof=
area = reglaSimpson(x,dof)
